# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sbns  
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv", sep=',')
df.head()
# Out:
#          Date  Sales Volume  Number of Visits  Stock Price
# 0  2023-01-01           120                50       150.25
# 1  2023-01-02           150                65       152.50
# 2  2023-01-03           135                55       151.75
# 3  2023-01-04           160                70       153.00
# 4  2023-01-05           145                60       152.25

# %%
dfm = df.resample('WE').agg({
    'Sales Volume': 'mean',
    'Number of Visits': 'mean',
    'Stock Price': 'mean'
})
plt.plot(df.index, df['Sales Volume'])
